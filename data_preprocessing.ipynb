# %%
import pandas

# %%
with open("data/positive.csv", encoding='utf-8') as f:
    df = pandas.read_csv(f, delimiter=";", header=None)

# %%
df
# Out:
#                         0           1                2   \
# 0       408906692374446080  1386325927  pleease_shut_up
# 1       408906692693221377  1386325927  alinakirpicheva
# 2       408906695083954177  1386325927        EvgeshaRe
# 3       408906695356973056  1386325927    ikonnikova_21
# 4       408906761416867842  1386325943        JumpyAlex
# 5       408906761769598976  1386325943  JustinB94262583
# 6       408906762436481024  1386325943       twinkleAYO
# 7       408906764114206720  1386325944      pycalyruhog
# 8       408906764608749568  1386325944        grishintv
# 9       408906765841870848  1386325944        alina_612
# 10      408906765896785920  1386325944       anvaharpew
# 11      408906815125340160  1386325956     kazerepiconu
# 12      408906818287828993  1386325957       Dane_Rider
# 13      408906819084754944  1386325957      Eugenia_lev
# 14      408906820019712002  1386325957   Vitaliy_Ivanov
# 15      408906854383620096  1386325965          __Brad_
# ...

# %%
with open("data/negative.csv", encoding='utf-8') as f:
    df2 = pandas.read_csv(f, delimiter=";", header=None)

# %%
df2
# Out:
#                         0           1                2   \
# 0       408906762813579264  1386325944  dugarchikbellko
# 1       408906818262687744  1386325957     nugemycejela
# 2       408906858515398656  1386325966          4post21
# 3       408906914437685248  1386325980         Poliwake
# 4       408906914723295232  1386325980       capyvixowe
# 5       408906915704737792  1386325980      nunejibaduq
# 6       408906973623504896  1386325994        Donna_132
# 7       408907184160776192  1386326044         Darynka_
# 8       408907406652231680  1386326097     mejagurijope
# 9       408907447303413760  1386326107        Ira_frank
# 10      408907490869272578  1386326117   MISS_SUAREZ_A3
# 11      408907543818153984  1386326130   Yana1966yanaRu
# 12      408907543889854465  1386326130        orangKoks
# 13      408907545122996225  1386326130        DMastattt
# 14      408907643198377984  1386326153    Michella_Bona
# 15      408907777776824320  1386326186         ermokina
# ...

# %%
df = df.append(df2)

# %%
df = df[[3,4]]

# %%
df
# Out:
#                                                         3  4
# 0       @first_timee хоть я и школота, но поверь, у на...  1
# 1       Да, все-таки он немного похож на него. Но мой ...  1
# 2       RT @KatiaCheh: Ну ты идиотка) я испугалась за ...  1
# 3       RT @digger2912: "Кто то в углу сидит и погибае...  1
# 4       @irina_dyshkant Вот что значит страшилка :D\nН...  1
# 5       ну любишь или нет? — Я не знаю кто ты бля:D ht...  1
# 6       RT @SpoonLamer: Ох,900 :D ну это конечно же @t...  1
# 7       RT @veregijytaqo: У тебя есть ухажёр? Нет - мо...  1
# 8       Поприветствуем моего нового читателя @Alexey17...  1
# 9       Теперь у меня есть частичка Сиднея :) #Sydney ...  1
# 10      Люблю маму и папу!!!!а в остальное я так...-вл...  1
# 11      RT @dicyziqecida: Как-то я забыла, что вчера п...  1
# 12      @MrsRourke_s_tit @_vivante @dyu_bryun так было...  1
# 13      @Kruglova_Julia_  дааааа))\nТы... Ты... Ты и т...  1
# ...

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df
# Out:
#                                                         3  4
# 0       Делаю пробное печенье по рецепту makeupkaty , ...  1
# 1       Опять я катаюсь по городу и натыкаюсь на всяки...  1
# 2       пришлите фотографию себя и своего ребенка, на ... -1
# 3       чем больше юзаю мак, тем больше раздражает ПиСи ( -1
# 4       Обыдно... Выехал на ИС-е. Набил 6 фрагов, а во... -1
# 5       @thisiryanross @berkooot_cku @LetoSofyya прост...  1
# 6       Доброго утра, друзья!! Пусть в вашей жизни буд...  1
# 7       @Belka_burunduk много чего не очень приятного ...  1
# 8             я не могу в это поверить, это просто ужас(( -1
# 9              уж лучше бы меня парень бросил, а не это ( -1
# 10      RT @hotumemasad: Мой любимый сайтик drmr.ru на... -1
# 11      Девки, кто за то чтобы хачи перестали уже нас ...  1
# 12      @Vetaaaaaa ахах, Лизааааа, ну вот так вот:) сп...  1
# 13      Я не понимаю где по телику "Один дома"??\nСнег... -1
# ...

# %%
len(df)
# Out:
# 226834

# %%
df.columns = ["text", "clas"]
df.index.name = "id"

# %%
df.loc[df.clas == -1, "clas"] = 0

# %%
df
# Out:
#                                                      text  clas
# id
# 0       Делаю пробное печенье по рецепту makeupkaty , ...     1
# 1       Опять я катаюсь по городу и натыкаюсь на всяки...     1
# 2       пришлите фотографию себя и своего ребенка, на ...     0
# 3       чем больше юзаю мак, тем больше раздражает ПиСи (     0
# 4       Обыдно... Выехал на ИС-е. Набил 6 фрагов, а во...     0
# 5       @thisiryanross @berkooot_cku @LetoSofyya прост...     1
# 6       Доброго утра, друзья!! Пусть в вашей жизни буд...     1
# 7       @Belka_burunduk много чего не очень приятного ...     1
# 8             я не могу в это поверить, это просто ужас((     0
# 9              уж лучше бы меня парень бросил, а не это (     0
# 10      RT @hotumemasad: Мой любимый сайтик drmr.ru на...     0
# 11      Девки, кто за то чтобы хачи перестали уже нас ...     1
# 12      @Vetaaaaaa ахах, Лизааааа, ну вот так вот:) сп...     1
# 13      Я не понимаю где по телику "Один дома"??\nСнег...     0
# ...

# %%
train = df[:int(len(df)*0.8)]
val = df[int(len(df)*0.8):int(len(df)*0.9)]
test = df[int(len(df)*0.9):]

# %%
test_public = test.iloc[:, [0]]

# %%
test_public
# Out:
#                                                      text
# id
# 204150  Эта беспонтовая ревность съедает меня изнутри. :(
# 204151  Всегда знайте себе цену!) Вы лучшие, вы умнейш...
# 204152  RT @Kepochka: я бы хотела пообщаться Биллом и ...
# 204153  @innaskhayrullin @ayrat_net @ruslanziatdin он ...
# 204154  На Дожде надпись на экране на английском языке...
# 204155  @baconitsme да:с закончился первый сезон :( а ...
# 204156  я ждал((\nладно, пойду смотреть лайв\nчерез ча...
# 204157  Мне как-то сказали, что мой ник "Сигл" связан ...
# 204158        Совершенно нечего смотреть в кинотеатре : (
# 204159       в универ завтра к 9 ((((((((((((((((((((((((
# 204160  @mviv16 ты, наверное, хочешь пойти со мной кат...
# 204161  ... Не передать мои чувства на самом деле)))))...
# 204162        Чет сегодня Радио-Т лагает не по-детски. :(
# 204163  Аххахаха! Все, обязанности вечернего развлекуш...
# 204164  т, говорить только что сильно ему нравлюсь.Но ...
# ...

# %%
train.to_csv("data/train.csv", header=["text", "class"])
val.to_csv("data/val.csv", header=["text", "class"])
test_public.to_csv("data/test.csv", header=["text"])

# %%
test_private = test.iloc[:, [1]]

# %%
test_private.to_csv("data/ground_truth.csv", header=["class"])

# %%
from random import choice
random_submit = test_private.applymap(lambda _: choice([0,1]))

# %%
random_submit
# Out:
#         clas
# id
# 204150     1
# 204151     0
# 204152     1
# 204153     0
# 204154     0
# 204155     1
# 204156     1
# 204157     0
# 204158     1
# 204159     1
# 204160     0
# 204161     0
# 204162     1
# 204163     0
# 204164     0
# 204165     0
# 204166     1
# 204167     1
# 204168     0
# 204169     1
# 204170     1
# 204171     0
# 204172     1
# 204173     0
# 204174     0
# 204175     0
# 204176     0
# 204177     0
# 204178     0
# 204179     1
# ...      ...
# 226804     0
# 226805     0
# 226806     1
# 226807     0
# 226808     0
# 226809     1
# 226810     1
# 226811     0
# 226812     1
# 226813     1
# 226814     1
# 226815     0
# 226816     0
# 226817     1
# 226818     0
# 226819     1
# 226820     0
# 226821     1
# 226822     1
# 226823     1
# 226824     0
# 226825     1
# 226826     0
# 226827     1
# 226828     0
# 226829     0
# 226830     1
# 226831     0
# 226832     0
# 226833     0
#
# [22684 rows x 1 columns]

# %%
random_submit.to_csv("data/random_submit.csv", header=["class"])
